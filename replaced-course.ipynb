# %%
import pandas as pd
data = pd.read_csv("Predict Academic Success - data.csv")

# %%
# Define the mapping of course codes to course names
mapped_course = {
    33: "Biofuel Production Technologies", 171: "Animation and Multimedia Design",8014: "Social Service (evening attendance)", 9003: "Agronomy",9070: "Communication Design",9085:"Veterinary Nursing", 9119: "Informatics Engineering", 9130: "Equinculture", 9147: "Management",9238: "Social Service",9254: "Tourism",9500: "Nursing",9556: "Oral Hygiene", 9670: "Advertising and Marketing Management",9773: "Journalism and Communication",9853: "Basic Education",9991: "Management (evening attendance)"
}

# %%
# Replace course codes with their corresponding course names
data["Course"] = data["Course"].replace(mapped_course)

# %%
data
# Out:
#       Marital status  Application mode  Application order  \
# 0                  1                17                  5
# 1                  1                15                  1
# 2                  1                 1                  5
# 3                  1                17                  2
# 4                  2                39                  1
# ...              ...               ...                ...
# 4419               1                 1                  6
# 4420               1                 1                  2
# 4421               1                 1                  1
# 4422               1                 1                  1
# 4423               1                10                  1
#
#                                    Course  Daytime/evening attendance\t  \
# 0         Animation and Multimedia Design                             1
# 1                                 Tourism                             1
# ...

# %%
data.to_csv('Predict_Academic_Success_Modified.csv', index=False)
